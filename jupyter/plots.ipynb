# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../orchestrator_results_1667145397.csv')  
df
# Out:
#             time  num_nodes  estimated_nodes_num         utilisation  \
# 0       0.000000          1                    1                None
# 1       5.175170          1                    1                None
# 2      10.337008          1                    1                None
# 3      15.499361          1                    1                None
# 4      20.657822          1                    1                None
# ..           ...        ...                  ...                 ...
# 314  1621.322670          4                    5  0.9841535162511674
# 315  1626.485696          4                    5  0.9841535162511674
# 316  1631.651995          4                    5  0.9842950014237591
# 317  1636.809928          4                    5  0.9842950014237591
# 318  1641.966922          4                    5  0.9842950014237591
#
#             arrival_rate  service_rate total_average_response_time
# 0                   None      0.009524                        None
# 1                   None      0.009524                        None
# 2                   None      0.009524                        None
# 3                   None      0.009524                        None
# 4                   None      0.009524                        None
# ..                   ...           ...                         ...
# 314    0.037491562523854      0.038095          119.41468068212271
# 315    0.037491562523854      0.038095          119.41468068212271
# 316  0.03749695243519083      0.038095          119.41468068212271
# 317  0.03749695243519083      0.038095          119.41468068212271
# 318  0.03749695243519083      0.038095          119.41468068212271
#
# [319 rows x 7 columns]

# %%
a = df[['time','utilisation']]
a = a.mask(a.eq('None')).dropna()
a['utilisation'] = a['utilisation'].astype(float)
plt.plot(a[["time"]], a[["utilisation"]], label='utilization')
plt.legend()
plt.show()

# %%
c = df[['time','arrival_rate']]
c = c.mask(c.eq('None')).dropna()
c['arrival_rate'] = c['arrival_rate'].astype(float)
plt.plot(c[["time"]], c[["arrival_rate"]], label='arrival rate')
plt.legend()
plt.show()

# %%
# SAME AS NUM OF NODES
# d = df[['time','service_rate']]
# d = d.mask(d.eq('None')).dropna()
# d['service_rate'] = d['service_rate'].astype(float)
# plt.plot(d[["time"]], d[["service_rate"]], label='service_rate')
# plt.legend()
# plt.show()

# %%
b = df[['time','num_nodes','estimated_nodes_num']]
plt.plot(b[["time"]], b[["num_nodes"]],label="number of nodes")
# plt.plot(b[["time"]], b[["estimated_nodes_num"]],label="estimated number of nodes")
plt.legend(loc="upper left")
plt.show()

# %%
b = df[['time','total_average_response_time']]
b = b.mask(b.eq('None')).dropna()
b['total_average_response_time'] = b['total_average_response_time'].astype(float)
plt.plot(b[["time"]], b[["total_average_response_time"]])
plt.show()
